# %%
import os
import pandas as pd
import zipfile

# Import all csv files inside the specified folder
zip_file_path = 'dataset.zip'

# Initialize an empty list to hold the dataframes
df_list = []

with zipfile.ZipFile(zip_file_path, 'r') as z:
    for filename in z.namelist():
        if filename.endswith('.csv'):
            with z.open(filename) as csvfile:
                df = pd.read_csv(csvfile)
                country_code = os.path.basename(filename)[:2]
                df['country'] = country_code
                df_list.append(df)
# Out:
# C:\Users\91902\AppData\Local\Temp\ipykernel_5384\3826469794.py:15: DtypeWarning: Columns (1,2,3,4,6,7,12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csvfile)

# %%
import pandas as pd

def filter_last_3_months(df):
    # Adjust the format to include time
    df['trending_date'] = pd.to_datetime(df['trending_date'], format='%Y-%m-%d %H:%M:%S')
    df['publishedAt'] = pd.to_datetime(df['publishedAt'], format='%Y-%m-%d %H:%M:%S')
    
    # Get the most recent date in the 'trending_date' column
    most_recent_date = df['trending_date'].max()
    
    # Calculate the date 3 months before the most recent date
    three_months_ago = most_recent_date - pd.DateOffset(months=3)
    
    # Filter the DataFrame to only include rows from the last 3 months
    filtered_df = df[df['trending_date'] >= three_months_ago]
    
    return filtered_df

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df['publishedAt'] = pd.to_datetime(df['publishedAt'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
df.shape
# Out:
# (799204, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799204 entries, 0 to 799203
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           750052 non-null  object
#  1   title              112691 non-null  object
#  2   publishedAt        112229 non-null  datetime64[ns]
#  3   channelId          112229 non-null  object
#  4   channelTitle       112229 non-null  object
#  5   categoryId         112229 non-null  float64
#  6   trending_date      112229 non-null  datetime64[ns]
#  7   tags               112229 non-null  object
#  8   view_count         112229 non-null  float64
#  9   likes              112229 non-null  float64
#  10  dislikes           112229 non-null  float64
#  11  comment_count      112229 non-null  float64
#  12  thumbnail_link     112229 non-null  object
#  13  comments_disabled  112229 non-null  object
#  14  ratings_disabled   112229 non-null  object
#  15  description        111565 non-null  object
#  16  country            799204 non-null  object
# dtypes: datetime64[ns](2), float64(5), object(10)
# memory usage: 103.7+ MB

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  b_l1IP_6psY  Watch Out (Official Audio) Sidhu Moose Wala | ...
# 1  IeFWNtMo1Fs         THE GARFIELD MOVIE - Official Trailer (HD)
# 2  xlyrt5eAtKI                    Red Velvet 레드벨벳 'Chill Kill' MV
# 3  9t2Y5kPp7fM                            Even Fancier: Paintings
# 4  _qtSGh9yjs4  Watch his reaction when he’s told he’s a GOOD ...
#
#            publishedAt                 channelId                 channelTitle  \
# 0  2023-11-12 06:30:11  UC9ChdqQRCaZmTCwSJ49tcbw             Sidhu Moose Wala
# 1  2023-11-13 14:00:22  UCz97F7dMxBNOfGYu3rx8aCw  Sony Pictures Entertainment
# 2  2023-11-13 09:01:12  UCEf_Bc-KVd7onSeifS3py9g                       SMTOWN
# 3  2023-11-13 14:44:09  UC8Q7XEy86Q7T-3kNpNjYgwA               Incognito Mode
# 4  2023-11-13 19:01:18  UCGisihUQxb3_gE7Qzffyp4g                 Rocky Kanaka
#
#    categoryId trending_date  \
# 0        10.0    2023-11-14
# 1        24.0    2023-11-14
# 2        10.0    2023-11-14
# 3        23.0    2023-11-14
# 4        24.0    2023-11-14
#
#                                                 tags  view_count      likes  \
# 0  sidhu moosewala|sidhu moosewala latest song|si...  12333431.0  2032227.0
# 1                                             [None]   4617407.0    89259.0
# 2  Red Velvet|레드벨벳|레벨|RV|아이린|웬디|슬기|조이|예리|irene|we...   5296169.0   468366.0
# 3  i am become fancy|fancy paintings|paint|intern...    645036.0    54666.0
# 4  rocky kanaka|dogs|dog|dog rescue|rescue dog|ho...    699331.0    31888.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       0.0       529332.0  https://i.ytimg.com/vi/b_l1IP_6psY/default.jpg
# 1       0.0         7750.0  https://i.ytimg.com/vi/IeFWNtMo1Fs/default.jpg
# 2       0.0        23839.0  https://i.ytimg.com/vi/xlyrt5eAtKI/default.jpg
# 3       0.0         2348.0  https://i.ytimg.com/vi/9t2Y5kPp7fM/default.jpg
# 4       0.0         4507.0  https://i.ytimg.com/vi/_qtSGh9yjs4/default.jpg
#
#   comments_disabled ratings_disabled  \
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False
#
#                                          description country
# 0  Sidhu Moose Wala Presents Song - Watch OutSing...      Yo
# 1  Monday just got a whole lot better - watch the...      Yo
# 2  Red Velvet's 3rd album Chill Kill is out!Liste...      Yo
# 3  🌏 Get exclusive NordVPN deal here ➵  https://N...      Yo
# 4  Special thanks to all of you for the support s...      Yo

# %%
df.tail()
# Out:
#            video_id                                              title  \
# 799199  HNIwPxrmWwg  LOS PRIMEROS PASOS DE MI HIJA ISABELLA😍😱 Carlo...
# 799200  oMMWFKilkKg  LA MAETA ME DIO UN SUSTO A LA SALIDA DASITO JU...
# 799201  bYTbitvw5Ks         ASÍ OCURRIÓ EL CAMI0N4Z0 EN ELOTA, SINALOA
# 799202  HDZ7G5uSp74  La Historia de Poppy Playtime Chapter 3 EXPLIC...
# 799203  cdG-F7CcIMs  Carne asada en el Mar | Vlog Ensenada | La Cap...
#
#                 publishedAt                 channelId  channelTitle  \
# 799199  2024-02-01 00:42:05  UCfSR85gldcGH9a18QhuobGA  Carlos Feria
# 799200  2024-01-31 23:12:10  UCNnIkOZgbDb82SuZfd3cKwg        Dasito
# 799201  2024-01-31 02:28:25  UCEHmkaqxzz8irAYATou27dw  LINK Sinaloa
# 799202  2024-01-31 17:00:22  UCassa1LNXUUGx7RZ5bsZYpA     Nintendúo
# 799203  2024-01-29 22:00:15  UCEwl20VxZ3AwOgiKMZtI1GQ    La Capital
#
#         categoryId trending_date  \
# 799199        22.0    2024-02-14
# 799200        20.0    2024-02-14
# 799201        25.0    2024-02-14
# 799202        20.0    2024-02-14
# 799203        26.0    2024-02-14
#
#                                                      tags  view_count  \
# 799199  MI HIJA ISABELLA DA SUS PRIMEROS PASOS😍|PRIMER...   1471920.0
# 799200  dasito|dacito|gameplay español latino|poppy pl...   1015641.0
# 799201  camionazo elota|accidente elota|camionazo maxi...    279764.0
# 799202  nintendo|nintenduo|nintendo duo|nintendo switc...   1171127.0
# 799203  ensenada mexico|tacos pescado|carne asada|atun...   1636064.0
#
#           likes  dislikes  comment_count  \
# 799199  38709.0       0.0         1605.0
# 799200  22441.0       0.0         2217.0
# 799201   1842.0       0.0          147.0
# 799202  30258.0       0.0         1216.0
# 799203  82931.0       0.0         1964.0
#
#                                         thumbnail_link comments_disabled  \
# 799199  https://i.ytimg.com/vi/HNIwPxrmWwg/default.jpg             False
# 799200  https://i.ytimg.com/vi/oMMWFKilkKg/default.jpg             False
# 799201  https://i.ytimg.com/vi/bYTbitvw5Ks/default.jpg             False
# 799202  https://i.ytimg.com/vi/HDZ7G5uSp74/default.jpg             False
# 799203  https://i.ytimg.com/vi/cdG-F7CcIMs/default.jpg             False
#
#        ratings_disabled                                        description  \
# 799199            False  FUE INCREIBLE VER COMO CAMINABA SOLA MI BEBE I...
# 799200            False  YA NO VOY A QUERER IR A LA ESCUELA DESPUES DE ...
# 799201            False  Durante horas laboraron los cuerpos de auxilio...
# 799202            False  Descubre la historia completa de Poppy Playtim...
# 799203            False  Contacto directo: oscarlacapital@gmail.com————...
#
#        country
# 799199      Yo
# 799200      Yo
# 799201      Yo
# 799202      Yo
# 799203      Yo

# %%
min_date = df['trending_date'].min()
max_date = df['trending_date'].max()

# %%
min_date
# Out:
# Timestamp('2023-11-14 00:00:00')

# %%
max_date
# Out:
# Timestamp('2024-02-14 00:00:00')

# %%
df.to_csv('YouTube-Trending-Video.csv', index=False)

# %%
mydata = pd.read_csv('YouTube-Trending-Video.csv')
# Out:
# C:\Users\91902\AppData\Local\Temp\ipykernel_5384\1382469883.py:1: DtypeWarning: Columns (1,2,3,4,6,7,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   mydata = pd.read_csv('YouTube-Trending-Video.csv')

# %%
mydata.tail()
# Out:
#            video_id                                              title  \
# 799199  HNIwPxrmWwg  LOS PRIMEROS PASOS DE MI HIJA ISABELLA😍😱 Carlo...
# 799200  oMMWFKilkKg  LA MAETA ME DIO UN SUSTO A LA SALIDA DASITO JU...
# 799201  bYTbitvw5Ks         ASÍ OCURRIÓ EL CAMI0N4Z0 EN ELOTA, SINALOA
# 799202  HDZ7G5uSp74  La Historia de Poppy Playtime Chapter 3 EXPLIC...
# 799203  cdG-F7CcIMs  Carne asada en el Mar | Vlog Ensenada | La Cap...
#
#                 publishedAt                 channelId  channelTitle  \
# 799199  2024-02-01 00:42:05  UCfSR85gldcGH9a18QhuobGA  Carlos Feria
# 799200  2024-01-31 23:12:10  UCNnIkOZgbDb82SuZfd3cKwg        Dasito
# 799201  2024-01-31 02:28:25  UCEHmkaqxzz8irAYATou27dw  LINK Sinaloa
# 799202  2024-01-31 17:00:22  UCassa1LNXUUGx7RZ5bsZYpA     Nintendúo
# 799203  2024-01-29 22:00:15  UCEwl20VxZ3AwOgiKMZtI1GQ    La Capital
#
#         categoryId trending_date  \
# 799199        22.0    2024-02-14
# 799200        20.0    2024-02-14
# 799201        25.0    2024-02-14
# 799202        20.0    2024-02-14
# 799203        26.0    2024-02-14
#
#                                                      tags  view_count  \
# 799199  MI HIJA ISABELLA DA SUS PRIMEROS PASOS😍|PRIMER...   1471920.0
# 799200  dasito|dacito|gameplay español latino|poppy pl...   1015641.0
# 799201  camionazo elota|accidente elota|camionazo maxi...    279764.0
# 799202  nintendo|nintenduo|nintendo duo|nintendo switc...   1171127.0
# 799203  ensenada mexico|tacos pescado|carne asada|atun...   1636064.0
#
#           likes  dislikes  comment_count  \
# 799199  38709.0       0.0         1605.0
# 799200  22441.0       0.0         2217.0
# 799201   1842.0       0.0          147.0
# 799202  30258.0       0.0         1216.0
# 799203  82931.0       0.0         1964.0
#
#                                         thumbnail_link comments_disabled  \
# 799199  https://i.ytimg.com/vi/HNIwPxrmWwg/default.jpg             False
# 799200  https://i.ytimg.com/vi/oMMWFKilkKg/default.jpg             False
# 799201  https://i.ytimg.com/vi/bYTbitvw5Ks/default.jpg             False
# 799202  https://i.ytimg.com/vi/HDZ7G5uSp74/default.jpg             False
# 799203  https://i.ytimg.com/vi/cdG-F7CcIMs/default.jpg             False
#
#        ratings_disabled                                        description  \
# 799199            False  FUE INCREIBLE VER COMO CAMINABA SOLA MI BEBE I...
# 799200            False  YA NO VOY A QUERER IR A LA ESCUELA DESPUES DE ...
# 799201            False  Durante horas laboraron los cuerpos de auxilio...
# 799202            False  Descubre la historia completa de Poppy Playtim...
# 799203            False  Contacto directo: oscarlacapital@gmail.com————...
#
#        country
# 799199      Yo
# 799200      Yo
# 799201      Yo
# 799202      Yo
# 799203      Yo
