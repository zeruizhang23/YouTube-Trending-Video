# %%
import numpy as np
import pandas as pd

# %%
us = pd.read_csv('~/Downloads/archive/US_youtube_trending_data.csv')

# %%
us.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
us.shape
# Out:
# (256387, 16)

# %%
us.columns
# Out:
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'view_count', 'likes',
#        'dislikes', 'comment_count', 'thumbnail_link', 'comments_disabled',
#        'ratings_disabled', 'description'],
#       dtype='object')

# %%
us['trending_date']=pd.to_datetime(us['trending_date'],format='%Y-%m-%dT%H:%M:%SZ')
us['publishedAt']=pd.to_datetime(us['publishedAt'],format='%Y-%m-%dT%H:%M:%SZ')

# %%
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256387 entries, 0 to 256386
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           256387 non-null  object
#  1   title              256387 non-null  object
#  2   publishedAt        256387 non-null  datetime64[ns]
#  3   channelId          256387 non-null  object
#  4   channelTitle       256387 non-null  object
#  5   categoryId         256387 non-null  int64
#  6   trending_date      256387 non-null  datetime64[ns]
#  7   tags               256387 non-null  object
#  8   view_count         256387 non-null  int64
#  9   likes              256387 non-null  int64
#  10  dislikes           256387 non-null  int64
#  11  comment_count      256387 non-null  int64
#  12  thumbnail_link     256387 non-null  object
#  13  comments_disabled  256387 non-null  bool
#  14  ratings_disabled   256387 non-null  bool
# ...
