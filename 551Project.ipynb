# %%
import os
import pandas as pd

# Import all csv files inside the specified folder
folder_path = '/Users/zeruizhang/Downloads/archive'

# Initialize an empty list to hold the dataframes
df_list = []

for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        file_path = os.path.join(folder_path, file)
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        # Extract the first two characters of the file name to use as the country code
        country_code = file[:2]
        # Add a new column 'country' to the DataFrame with the country code
        df['country'] = country_code
        # Append the DataFrame to the list
        df_list.append(df)

# %%
import pandas as pd

def filter_last_3_months(df):
    # Convert columns to datetime
    df['trending_date'] = pd.to_datetime(df['trending_date'], format='%Y-%m-%dT%H:%M:%SZ')
    df['publishedAt'] = pd.to_datetime(df['publishedAt'], format='%Y-%m-%dT%H:%M:%SZ')
    
    # Get the most recent date in the 'trending_date' column
    most_recent_date = df['trending_date'].max()
    
    # Calculate the date 3 months before the most recent date
    three_months_ago = most_recent_date - pd.DateOffset(months=3)
    
    # Filter the DataFrame to only include rows from the last 3 months
    filtered_df = df[df['trending_date'] >= three_months_ago]
    
    return filtered_df

# %%
filtered_df_list = [filter_last_3_months(df) for df in df_list]

# Concatenate all the filtered DataFrames into one, name it 'df' (ready to analyze)
df = pd.concat(filtered_df_list, ignore_index=True)

# %%
df.shape
# Out:
# (195803, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195803 entries, 0 to 195802
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           195803 non-null  object
#  1   title              195803 non-null  object
#  2   publishedAt        195803 non-null  datetime64[ns]
#  3   channelId          195803 non-null  object
#  4   channelTitle       195803 non-null  object
#  5   categoryId         195803 non-null  int64
#  6   trending_date      195803 non-null  datetime64[ns]
#  7   tags               195803 non-null  object
#  8   view_count         195803 non-null  int64
#  9   likes              195803 non-null  int64
#  10  dislikes           195803 non-null  int64
#  11  comment_count      195803 non-null  int64
#  12  thumbnail_link     195803 non-null  object
#  13  comments_disabled  195803 non-null  bool
#  14  ratings_disabled   195803 non-null  bool
#  15  description        190146 non-null  object
#  16  country            195803 non-null  object
# dtypes: bool(2), datetime64[ns](2), int64(5), object(8)
# memory usage: 22.8+ MB

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  b_l1IP_6psY  Watch Out (Official Audio) Sidhu Moose Wala | ...
# 1  okAAL53Rj_0  Film Theory: The FNAF Movie Just Changed the L...
# 2  nxdh69enoSw        Traveling to the Strangest Country on Earth
# 3  idtvY5lN314         We're Giving Away $30 Million in Free Food
# 4  Z7r26_NqfLw     Can This Iron Chef Turn Panda Express Gourmet?
#
#           publishedAt                 channelId        channelTitle  \
# 0 2023-11-12 06:30:11  UC9ChdqQRCaZmTCwSJ49tcbw    Sidhu Moose Wala
# 1 2023-11-12 19:05:34  UC3sznuotAs2ohg_U__Jzj_Q  The Film Theorists
# 2 2023-11-12 18:01:06  UCvK4bOhULCpmLabd2pDMtnA          Yes Theory
# 3 2023-11-12 12:00:29  UCAiLfjNXkNv24uhpzUgPa6A  Beast Philanthropy
# 4 2023-11-12 14:00:17  UCVjlpEjEY9GpksqbEesJnNA           mrnigelng
#
#    categoryId trending_date  \
# 0          10    2023-11-13
# 1           1    2023-11-13
# 2          24    2023-11-13
# 3          22    2023-11-13
# 4          23    2023-11-13
#
#                                                 tags  view_count    likes  \
# 0  sidhu moosewala|sidhu moosewala latest song|si...     9966312  1859773
# 1  fnaf|five nights at freddy’s|five nights at fr...     2255318   157782
# 2  yestheory|seek discomfort|yes theory strangers...      595532    38546
# 3                                             [None]     2883764   303587
# 4               nigel ng|uncle roger|nigel ng comedy      963594    50632
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0         0         505944  https://i.ytimg.com/vi/b_l1IP_6psY/default.jpg
# 1         0           6009  https://i.ytimg.com/vi/okAAL53Rj_0/default.jpg
# 2         0           9362  https://i.ytimg.com/vi/nxdh69enoSw/default.jpg
# 3         0          10743  https://i.ytimg.com/vi/idtvY5lN314/default.jpg
# 4         0           1627  https://i.ytimg.com/vi/Z7r26_NqfLw/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description country
# 0  Sidhu Moose Wala Presents Song - Watch OutSing...      CA
# 1  *🆕 Don’t Miss Our Latest Theorywear Drop!*Shop...      CA
# 2  Visit http://magictravel.ai/yestheory to enter...      CA
# 3  Thank you to our partner @Ibotta for sponsorin...      CA
# 4  Use my code UNCLEROGER to get $15 off your fir...      CA

# %%
df.tail()
# Out:
#            video_id                                              title  \
# 195798  k24xKZ_Oajs            Apex Legends: Breakout Gameplay Trailer
# 195799  ZdpBufCMnyc  JE DORS DANS MA PIÈCE SECRÈTE (et je l’ai enco...
# 195800  HBQGhbE0jno  Daaaaaalí de Quentin Dupieux : Edouard Baer et...
# 195801  vVybduQrcF8  Puisque c’est complet en 7h j’rajoute une date 🤟🏾
# 195802  deS1N039wl0                        24h avec Apple Vision Pro !
#
#                publishedAt                 channelId    channelTitle  \
# 195798 2024-02-08 16:00:14  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends
# 195799 2024-02-07 17:00:09  UCgl_xdd0kH27vMIZnE-_17w           ALEKS
# 195800 2024-02-06 22:27:23  UC1ObaaFz4XHVPN2T5IFsU4w           L'Obs
# 195801 2024-02-07 17:03:04  UCXdHJabqwLJ3NvPfx6XmS5Q           Ninho
# 195802 2024-02-06 15:33:23  UCaybrunQi8xWgPMgv1AYBHw  TheiCollection
#
#         categoryId trending_date  \
# 195798          20    2024-02-13
# 195799          24    2024-02-13
# 195800          25    2024-02-13
# 195801          10    2024-02-13
# 195802          28    2024-02-13
#
#                                                      tags  view_count  likes  \
# 195798  apex legends|apex legends season 20|apex legen...     1318418  49069
# 195799  pièce secrète|secret|pièce|dormir|je dors|alek...      156093  10093
# 195800  Cinéma|Daaaaaali|Dali|Dupieux|Edouard Baer|Jon...      245785   2019
# 195801  Ninho|Binks to binks 5 Musique|Rap|Clip offici...      108865   5888
# 195802  Vision Pro|Apple Vision Pro|Apple Vision Pro F...      711108  26733
#
#         dislikes  comment_count  \
# 195798         0           2573
# 195799         0            235
# 195800         0            107
# 195801         0            268
# 195802         0           1788
#
#                                         thumbnail_link  comments_disabled  \
# 195798  https://i.ytimg.com/vi/k24xKZ_Oajs/default.jpg              False
# 195799  https://i.ytimg.com/vi/ZdpBufCMnyc/default.jpg              False
# 195800  https://i.ytimg.com/vi/HBQGhbE0jno/default.jpg              False
# 195801  https://i.ytimg.com/vi/vVybduQrcF8/default.jpg              False
# 195802  https://i.ytimg.com/vi/deS1N039wl0/default.jpg              False
#
#         ratings_disabled                                        description  \
# 195798             False  Welcome to the biggest Anniversary Season yet!...
# 195799             False  Je DORS dans ma Pièce SECRÈTE et je l'ai améli...
# 195800             False  Dans le nouveau film de Quentin Dupieux, cinq ...
# 195801             False  Puisque c’est complet en 7h j’rajoute une date...
# 195802             False  Merci à Nord VPN de m'avoir accompagné sur ce ...
#
#        country
# 195798      FR
# 195799      FR
# 195800      FR
# 195801      FR
# 195802      FR

# %%
min_date = df['trending_date'].min()
max_date = df['trending_date'].max()

# %%
min_date
# Out:
# Timestamp('2023-11-13 00:00:00')

# %%
max_date
# Out:
# Timestamp('2024-02-13 00:00:00')
