# %%
import pandas as pd
import json

# %%
us = pd.read_csv('US_youtube_trending_data.csv')
us['country'] = 'US'


with open('US_category_id.json', 'r') as file:
    categories_json = json.load(file)

us_category_mapping = {int(item['id']): item['snippet']['title'] for item in categories_json['items']}
us['categoryId'] = us['categoryId'].astype(int)
us['categoryName'] = us['categoryId'].map(us_category_mapping)

us.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
canada = pd.read_csv('CA_youtube_trending_data.csv')
canada['country'] = 'Canada'

with open('CA_category_id.json', 'r') as file:
    categories_json = json.load(file)

ca_category_mapping = {int(item['id']): item['snippet']['title'] for item in categories_json['items']}
canada['categoryId'] = canada['categoryId'].astype(int)
canada['categoryName'] = canada['categoryId'].map(ca_category_mapping)

canada.head()
# Out:
#       video_id                                              title  \
# 0  KX06ksuS6Xo  Diljit Dosanjh: CLASH (Official) Music Video |...
# 1  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 2  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 3  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T07:30:02Z  UCZRdNleCgW-BGUJf-bbjzQg  Diljit Dosanjh          10
# 1  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 2  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 3  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
mexico = pd.read_csv('MX_youtube_trending_data.csv')
mexico['country'] = 'Mexico'

with open('MX_category_id.json', 'r') as file:
    categories_json = json.load(file)

mx_category_mapping = {int(item['id']): item['snippet']['title'] for item in categories_json['items']}
mexico['categoryId'] = mexico['categoryId'].astype(int)
mexico['categoryName'] = mexico['categoryId'].map(mx_category_mapping)

mexico.head()
# Out:
#       video_id                                              title  \
# 0  SsWHMAhshPQ  Ovi x Natanael Cano x Aleman x Big Soto - Veng...
# 1  JOaeND0xUNk  Belinda y Christian Nodal cantan De los besos ...
# 2  SV91jnGs--s        ¿QUIÉN HACE LOS MEJORES NUGGETS? | EL GUZII
# 3  QgX0zn5nMyk  Martha Figueroa se disculpa públicamente con N...
# 4  cKaM19oAwBM  MAQUILLAJE PARA KIMBERLY LOAIZA✨ RESISTENTE AL...
#
#             publishedAt                 channelId       channelTitle  \
# 0  2020-08-11T23:00:10Z  UC648rgJOboZlgcDbW00vTSA     Rancho Humilde
# 1  2020-08-11T18:03:06Z  UCNVrBkfp4_TG9x4h5kvLeAQ          TV Azteca
# 2  2020-08-11T19:57:02Z  UCuGn3ioftOo6jvHE1YK4Bfw           El Guzii
# 3  2020-08-11T15:57:47Z  UCJPd6seu4JK4PZjVVTWb0QA                Hoy
# 4  2020-08-11T21:55:08Z  UCs5w0QCxsEWz83vuQyOCnuA  Victor Guadarrama
#
#    categoryId         trending_date  \
# 0          10  2020-08-12T00:00:00Z
# 1          24  2020-08-12T00:00:00Z
# 2          26  2020-08-12T00:00:00Z
# ...

# %%
combined_data = pd.concat([us, canada, mexico])
combined_data.head()
combined_data.tail()
# Out:
#            video_id                                              title  \
# 256393  HNIwPxrmWwg  LOS PRIMEROS PASOS DE MI HIJA ISABELLA😍😱 Carlo...
# 256394  oMMWFKilkKg  LA MAETA ME DIO UN SUSTO A LA SALIDA DASITO JU...
# 256395  bYTbitvw5Ks         ASÍ OCURRIÓ EL CAMI0N4Z0 EN ELOTA, SINALOA
# 256396  HDZ7G5uSp74  La Historia de Poppy Playtime Chapter 3 EXPLIC...
# 256397  cdG-F7CcIMs  Carne asada en el Mar | Vlog Ensenada | La Cap...
#
#                  publishedAt                 channelId  channelTitle  \
# 256393  2024-02-01T00:42:05Z  UCfSR85gldcGH9a18QhuobGA  Carlos Feria
# 256394  2024-01-31T23:12:10Z  UCNnIkOZgbDb82SuZfd3cKwg        Dasito
# 256395  2024-01-31T02:28:25Z  UCEHmkaqxzz8irAYATou27dw  LINK Sinaloa
# 256396  2024-01-31T17:00:22Z  UCassa1LNXUUGx7RZ5bsZYpA     Nintendúo
# 256397  2024-01-29T22:00:15Z  UCEwl20VxZ3AwOgiKMZtI1GQ    La Capital
#
#         categoryId         trending_date  \
# 256393          22  2024-02-14T00:00:00Z
# ...

# %%
combined_data['trending_date'] = pd.to_datetime(combined_data['trending_date']).dt.date
combined_data['publishedAt'] = pd.to_datetime(combined_data['publishedAt']).dt.date


current_date = pd.to_datetime('today').date()


recent_data = combined_data[combined_data['trending_date'] >= current_date - pd.Timedelta(days=90)]

recent_data.tail()
# Out:
#            video_id                                              title  \
# 256393  HNIwPxrmWwg  LOS PRIMEROS PASOS DE MI HIJA ISABELLA😍😱 Carlo...
# 256394  oMMWFKilkKg  LA MAETA ME DIO UN SUSTO A LA SALIDA DASITO JU...
# 256395  bYTbitvw5Ks         ASÍ OCURRIÓ EL CAMI0N4Z0 EN ELOTA, SINALOA
# 256396  HDZ7G5uSp74  La Historia de Poppy Playtime Chapter 3 EXPLIC...
# 256397  cdG-F7CcIMs  Carne asada en el Mar | Vlog Ensenada | La Cap...
#
#        publishedAt                 channelId  channelTitle  categoryId  \
# 256393  2024-02-01  UCfSR85gldcGH9a18QhuobGA  Carlos Feria          22
# 256394  2024-01-31  UCNnIkOZgbDb82SuZfd3cKwg        Dasito          20
# 256395  2024-01-31  UCEHmkaqxzz8irAYATou27dw  LINK Sinaloa          25
# 256396  2024-01-31  UCassa1LNXUUGx7RZ5bsZYpA     Nintendúo          20
# 256397  2024-01-29  UCEwl20VxZ3AwOgiKMZtI1GQ    La Capital          26
#
#        trending_date                                               tags  \
# ...

# %%
#output file
recent_data.to_csv('/Users/marina/Desktop/YouTube-Trending-Video.csv', index=False)
